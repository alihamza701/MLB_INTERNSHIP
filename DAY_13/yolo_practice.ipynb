# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 5.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# %%
result = model("/content/An_Image.jpg")
# Out:
# image 1/1 /content/An_Image.jpg: 448x640 1 person, 166.8ms
# Speed: 3.8ms preprocess, 166.8ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)

# %%
result[0].save()
# Out:
# 'results_An_Image.jpg'

# %%
results = model("/content/multiple_images" ,  save = True , project = "/content/results_multiple_images" , name = "predictions")
# Out:
# image 1/4 /content/multiple_images/pexels-christina99999-38235551.jpg: 640x448 (no detections), 159.1ms
# image 2/4 /content/multiple_images/pexels-ludvighedenborg-5026754.jpg: 416x640 2 persons, 209.6ms
# image 3/4 /content/multiple_images/pexels-rey-mart-ramos-2160278748-38482483.jpg: 448x640 1 person, 243.1ms
# image 4/4 /content/multiple_images/pexels-urielluphoto-38121708.jpg: 448x640 1 bird, 218.1ms
# Speed: 4.6ms preprocess, 207.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/results_multiple_images/predictions
